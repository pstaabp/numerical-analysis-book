# %%
using Latexify

# %%
A = [ 2//3 2//7 1//5 43//15
1//3 1//7 -1//2 5//6
1//5 -3//7 2//5 -12//5]
# Out:
# 3×4 Matrix{Rational{Int64}}:
#  2//3   2//7   1//5   43//15
#  1//3   1//7  -1//2    5//6
#  1//5  -3//7   2//5  -12//5

# %%
A = [105*A[1,:]' ; 42*A[2,:]'; 35*A[3,:]']
latexify(A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{cccc}
# 70 & 30 & 21 & 301 \\
# 14 & 6 & -21 & 35 \\
# 7 & -15 & 14 & -84 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
A = [A[3,:]'; A[2,:]'; A[1,:]']
latexify(A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{cccc}
# 7 & -15 & 14 & -84 \\
# 14 & 6 & -21 & 35 \\
# 70 & 30 & 21 & 301 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
A = [A[1, :]';
  -2A[1, :]' + A[2, :]';
  -10A[1, :]' + A[3, :]'
]
# Out:
# 3×4 Matrix{Rational{Int64}}:
#  7  -15    14   -84
#  0   36   -49   203
#  0  180  -119  1141

# %%
A = [A[1,:]'
A[2,:]'
-5A[2,:]' + A[3,:]'
]
latexify(A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{cccc}
# 7 & -15 & 14 & -84 \\
# 0 & 36 & -49 & 203 \\
# 0 & 0 & 126 & 126 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
A = [A[1,:]'
A[2,:]'
A[3,:]'//126
]
latexify(A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{cccc}
# 7 & -15 & 14 & -84 \\
# 0 & 36 & -49 & 203 \\
# 0 & 0 & 1 & 1 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
A = [-14A[3,:]' + A[1,:]'
49A[3,:]' + A[2,:]'
A[3,:]'
]
latexify(A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{cccc}
# 7 & -15 & 0 & -98 \\
# 0 & 36 & 0 & 252 \\
# 0 & 0 & 1 & 1 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
A = [A[1,:]'
A[2,:]' // 36
A[3,:]'
]
latexify(A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{cccc}
# 7 & -15 & 0 & -98 \\
# 0 & 1 & 0 & 7 \\
# 0 & 0 & 1 & 1 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
A = [15A[2,:]' + A[1,:]'
A[2,:]'
A[3,:]'
]
latexify(A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{cccc}
# 7 & 0 & 0 & 7 \\
# 0 & 1 & 0 & 7 \\
# 0 & 0 & 1 & 1 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
π
